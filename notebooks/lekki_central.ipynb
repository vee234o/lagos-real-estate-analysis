# %%
import pandas as pd
df = pd.read_csv('Lekki_Central_Data.csv')

# %%
df
# Out:
#                                         title  location  \
# 0         3 bedroom flat / apartment for rent       NaN
# 1         2 bedroom flat / apartment for rent       NaN
# 2         2 bedroom flat / apartment for rent       NaN
# 3     4 bedroom semi-detached duplex for rent       NaN
# 4          4 bedroom terraced duplex for rent       NaN
# ...                                       ...       ...
# 1063      2 bedroom flat / apartment for rent       NaN
# 1064          Plaza / complex / mall for rent       NaN
# 1065      2 bedroom flat / apartment for rent       NaN
# 1066  4 bedroom semi-detached duplex for rent       NaN
# 1067                                      NaN       NaN
#
#                                        price  bedrooms  bathrooms  toilets  \
# 0                       ₦18,000,000per annum         3          3        4
# 1                        ₦6,000,000per annum         2          2        3
# ...
